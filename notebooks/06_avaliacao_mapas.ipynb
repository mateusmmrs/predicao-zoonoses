# %%
import pandas as pd
import geopandas as gpd
import folium
from branca.colormap import LinearColormap
import joblib

# Carregar modelo e dados mais recentes
# model = joblib.load('../models/best_model.pkl')
# df = pd.read_parquet('../data/processed/features.parquet')
# gdf = gpd.read_file('../data/external/municipios_geo.geojson')
print("Notebook pronto para mapas de risco!")
